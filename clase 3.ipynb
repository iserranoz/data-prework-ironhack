# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
import numpy as np

# %%
# Out:
# 3

# %%
data = pd.read_csv('SalesKaggle3.csv')

# %%
data
# Out:
#          Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0            2  Historical     1737127       0.0        0.0             D
# 1            3  Historical     3255963       0.0        0.0             D
# 2            4  Historical      612701       0.0        0.0             D
# 3            6  Historical      115883       1.0        1.0             D
# 4            7  Historical      863939       1.0        1.0             D
# ...        ...         ...         ...       ...        ...           ...
# 198912  208023      Active      109683       NaN        NaN             D
# 198913  208024      Active      416462       NaN        NaN             D
# 198914  208025      Active      658242       NaN        NaN             S
# 198915  208026      Active     2538340       NaN        NaN             S
# 198916  208027      Active      416662       NaN        NaN             D
#
#         ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  \
# ...

# %%
data.describe(include= 'all')
# Out:
#                 Order File_Type    SKU_number      SoldFlag     SoldCount  \
# count   198917.000000    198917  1.989170e+05  75996.000000  75996.000000
# unique            NaN         2           NaN           NaN           NaN
# top               NaN    Active           NaN           NaN           NaN
# freq              NaN    122921           NaN           NaN           NaN
# mean    106483.543242       NaN  8.613626e+05      0.171009      0.322306
# std      60136.716784       NaN  8.699794e+05      0.376519      1.168615
# min          2.000000       NaN  5.000100e+04      0.000000      0.000000
# 25%      55665.000000       NaN  2.172520e+05      0.000000      0.000000
# 50%     108569.000000       NaN  6.122080e+05      0.000000      0.000000
# 75%     158298.000000       NaN  9.047510e+05      0.000000      0.000000
# max     208027.000000       NaN  3.960788e+06      1.000000     73.000000
#
#        MarketingType  ReleaseNumber  New_Release_Flag  StrengthFactor  \
# ...

# %%
data.head()
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
# 2              0                 0        340464.0     46.00         2013
# 3              4                 1        334011.0    100.00         2006
# 4              2                 1       1287938.0    121.95         2010
#
#    ItemCount  LowUserPrice  LowNetPrice
# 0          8         28.97        31.84
# ...

# %%
data.sort_values(by='SoldCount', ascending = True)
# Out:
#          Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0            2  Historical     1737127       0.0        0.0             D
# 49114    55038  Historical      106684       0.0        0.0             S
# 49115    55039  Historical      107068       0.0        0.0             S
# 49116    55040  Historical      106606       0.0        0.0             S
# 49117    55041  Historical      106906       0.0        0.0             S
# ...        ...         ...         ...       ...        ...           ...
# 198912  208023      Active      109683       NaN        NaN             D
# 198913  208024      Active      416462       NaN        NaN             D
# 198914  208025      Active      658242       NaN        NaN             S
# 198915  208026      Active     2538340       NaN        NaN             S
# 198916  208027      Active      416662       NaN        NaN             D
#
#         ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  \
# ...

# %%
# revisar datos unicos de columnas
data.nunique()
# Out:
# Order               198917
# File_Type                2
# SKU_number          133360
# SoldFlag                 2
# SoldCount               37
# MarketingType            2
# ReleaseNumber           71
# New_Release_Flag         2
# StrengthFactor      197424
# PriceReg             11627
# ReleaseYear             85
# ItemCount              501
# LowUserPrice         12102
# LowNetPrice          15403
# dtype: int64

# %%
# FILTRAMOS EL DATAFRAME POR ACTIVOS E HISTORICOS Y CONTAMOS EL REGISTRO
print(data[data['File_Type'] == 'Historical']['SKU_number'].count())
data[data['File_Type'] == 'Active']['SKU_number'].count()
# Out:
# 75996
# 122921

# %%
data_active = data[data['File_Type'] == 'Active']
data_hist = data[data['File_Type'] == 'Historical']

# %%
data_active
# Out:
#          Order File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 75996    85107    Active      869734       NaN        NaN             S
# 75997    85108    Active     3741319       NaN        NaN             S
# 75998    85109    Active     3517789       NaN        NaN             S
# 75999    85110    Active     1455936       NaN        NaN             S
# 76000    85111    Active     2921480       NaN        NaN             S
# ...        ...       ...         ...       ...        ...           ...
# 198912  208023    Active      109683       NaN        NaN             D
# 198913  208024    Active      416462       NaN        NaN             D
# 198914  208025    Active      658242       NaN        NaN             S
# 198915  208026    Active     2538340       NaN        NaN             S
# 198916  208027    Active      416662       NaN        NaN             D
#
#         ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  \
# ...

# %%
 x = data_active['MarketingType'].value_counts()

# %%
x
# Out:
# S    40877
# D    35119
# Name: MarketingType, dtype: int64

# %%
print(x.plot.bar())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
y = data_hist['MarketingType'].value_counts()

# %%
y
# Out:
# D    62852
# S    60069
# Name: MarketingType, dtype: int64

# %%
y.plot.bar()

# %%
data_columns = ['PriceReg', 'ReleaseYear']
fig, ax = plt.subplots(len(data_columns), figsize = (16,12))
for i, col_val in enumerate(data_columns):
    
    sns.distplot(data_active[col_val], hist = True, ax = ax[i])
    #ax[i].set_title('Freq_dist ' +col_val, fontsize = 10)
    #ax[i].set_xlabel(col_val, fontsize = 8)
    #ax[i].set_ylabel('Count', fontsize = 8)

# %%
 sns.distplot(data_active['PriceReg'], hist = True)

# %%
data_hist
# Out:
#        Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0          2  Historical     1737127       0.0        0.0             D
# 1          3  Historical     3255963       0.0        0.0             D
# 2          4  Historical      612701       0.0        0.0             D
# 3          6  Historical      115883       1.0        1.0             D
# 4          7  Historical      863939       1.0        1.0             D
# ...      ...         ...         ...       ...        ...           ...
# 75991  85102  Historical      863599       0.0        0.0             S
# 75992  85103  Historical      614304       0.0        0.0             S
# 75993  85104  Historical      109021       0.0        0.0             S
# 75994  85105  Historical      658242       0.0        0.0             S
# 75995  85106  Historical     2538340       0.0        0.0             S
#
#        ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# ...

# %%
# reset de indices
data_hist = data_hist.reset_index(drop = True)

# %%
data_hist = data_hist.drop(['File_Type', 'Order','SKU_number', 'SoldFlag', 'MarketingType', 'ReleaseNumber', 'New_Release_Flag'], axis = 1)

# %%
sns.pairplot(data_hist)

# %%
data.isnull().values.any()
# Out:
# True

# %%
data.isnull()
# Out:
#         Order  File_Type  SKU_number  SoldFlag  SoldCount  MarketingType  \
# 0       False      False       False     False      False          False
# 1       False      False       False     False      False          False
# 2       False      False       False     False      False          False
# 3       False      False       False     False      False          False
# 4       False      False       False     False      False          False
# ...       ...        ...         ...       ...        ...            ...
# 198912  False      False       False      True       True          False
# 198913  False      False       False      True       True          False
# 198914  False      False       False      True       True          False
# 198915  False      False       False      True       True          False
# 198916  False      False       False      True       True          False
#
#         ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  \
# ...

# %%
data.isnull().sum()
# Out:
# Order               0
# File_Type           0
# SKU_number          0
# SoldFlag            0
# SoldCount           0
# MarketingType       0
# ReleaseNumber       0
# New_Release_Flag    0
# StrengthFactor      0
# PriceReg            0
# ReleaseYear         0
# ItemCount           0
# LowUserPrice        0
# LowNetPrice         0
# dtype: int64

# %%
data['SoldFlag'].fillna(0,inplace = True)
data['SoldCount'].fillna(0,inplace = True)

# %%
#lista_na = ['SoldFlag', 'SoldCount']
#for i in lista_na:
    #data[i].fillna(0, inplace = True)

# %%
sns.boxplot(y = data_hist['ReleaseYear'])

# %%
list3 = ['StrengthFactor', 'PriceReg', 'ReleaseYear']
fig, ax = plt.subplots(len(list3), figsize = (8,40))
for i, val in enumerate(list3):
    sns.boxplot(y = data_hist[val], ax = ax[i])
plt.show()

# %%
def percentile_based_outlier(data, threshold=95):
    diff = (100 - threshold) / 2
    minval, maxval = np.percentile(data, [diff, 100 - diff])
    return (data < minval) | (data > maxval)

col_names = ['StrengthFactor','PriceReg', 'ReleaseYear', 'ItemCount', 'LowUserPrice', 'LowNetPrice']

fig, ax = plt.subplots(len(col_names), figsize=(8,40))

for i, col_val in enumerate(col_names):
    x = data_hist[col_val][:1000]
    sns.distplot(x, ax=ax[i], rug=True, hist=False)
    outliers = x[percentile_based_outlier(x)]
    ax[i].plot(outliers, np.zeros_like(outliers), 'ro', clip_on=False)

    #ax[i].set_title('Outlier detection - {}'.format(col_val), fontsize=10)
    #ax[i].set_xlabel(col_val, fontsize=8)

plt.show()

# %%
outliers = percentile_based_outlier(x)

# %%
outliers
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: LowNetPrice, Length: 1000, dtype: bool

# %%
x[100:200]
# Out:
# 100    282.29
# 101    201.63
# 102     24.96
# 103    288.58
# 104     38.99
#         ...
# 195     62.84
# 196     33.99
# 197      7.99
# 198      7.95
# 199      5.03
# Name: LowNetPrice, Length: 100, dtype: float64

# %%
outliers2 = x[percentile_based_outlier(x)]
outliers2
# Out:
# 28       4.00
# 66       4.00
# 67       0.00
# 87     245.33
# 100    282.29
# 101    201.63
# 103    288.58
# 111    193.98
# 139      0.00
# 143    248.08
# 156    176.96
# 186    231.83
# 208      4.58
# 222      4.00
# 275    202.97
# 276    602.40
# 278    428.48
# 281    189.31
# 282    349.65
# 295    225.50
# 303    602.99
# 304    602.99
# 312      4.15
# 343      4.45
# 350      0.00
# 369    602.99
# 372    201.91
# 396    478.99
# 407      0.00
# 411      0.00
# 420      4.46
# 473      4.00
# 485    575.73
# 527    228.42
# 571      0.00
# 586    189.99
# 595      0.00
# 597      4.17
# 641      4.06
# 660    998.41
# 681      4.46
# 693      4.06
# 715      0.00
# 726      4.49
# 746      0.00
# 775      4.58
# 838    592.93
# 856      0.00
# 892    241.87
# 947      4.43
# Name: LowNetPrice, dtype: float64

# %%
data_hist
# Out:
#        Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0          2  Historical     1737127       0.0        0.0             D
# 1          3  Historical     3255963       0.0        0.0             D
# 2          4  Historical      612701       0.0        0.0             D
# 3          6  Historical      115883       1.0        1.0             D
# 4          7  Historical      863939       1.0        1.0             D
# ...      ...         ...         ...       ...        ...           ...
# 75991  85102  Historical      863599       0.0        0.0             S
# 75992  85103  Historical      614304       0.0        0.0             S
# 75993  85104  Historical      109021       0.0        0.0             S
# 75994  85105  Historical      658242       0.0        0.0             S
# 75995  85106  Historical     2538340       0.0        0.0             S
#
#        ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# ...

# %%
data_hist.corr()
# Out:
#                 SoldCount  StrengthFactor  PriceReg  ReleaseYear  ItemCount  \
# SoldCount        1.000000       -0.109237  0.056702     0.070090   0.224002
# StrengthFactor  -0.109237        1.000000 -0.043543    -0.355762  -0.293981
# PriceReg         0.056702       -0.043543  1.000000     0.047376   0.061155
# ReleaseYear      0.070090       -0.355762  0.047376     1.000000   0.092392
# ItemCount        0.224002       -0.293981  0.061155     0.092392   1.000000
# LowUserPrice     0.042608        0.027959  0.171063     0.004307   0.028667
# LowNetPrice     -0.011965        0.030402  0.098846     0.007832  -0.081048
#
#                 LowUserPrice  LowNetPrice
# SoldCount           0.042608    -0.011965
# StrengthFactor      0.027959     0.030402
# PriceReg            0.171063     0.098846
# ReleaseYear         0.004307     0.007832
# ItemCount           0.028667    -0.081048
# LowUserPrice        1.000000     0.036565
# LowNetPrice         0.036565     1.000000

# %%
f, ax = plt.subplots(figsize=(10,8))
corr = data_hist.corr()
sns.heatmap(corr,
           xticklabels=corr.columns.values,
           yticklabels=corr.columns.values)

# %%
1 + 2
# Out:
# 3

# %%
1 + 2
# Out:
# 3

# %%
data.head()
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
# 2              0                 0        340464.0     46.00         2013
# 3              4                 1        334011.0    100.00         2006
# 4              2                 1       1287938.0    121.95         2010
#
#    ItemCount  LowUserPrice  LowNetPrice
# 0          8         28.97        31.84
# ...
